# %% [markdown]
# # Find Fine Wine
# - How can you dine without some fine wine?

# %% [markdown]
# ## Goal
# * Discover drivers of wine quality
# * Use drivers to develop clusters or groupings
# * Use drivers and clusters to develop a machine learning model to predict wine quality

# %% [markdown]
# ## Imports

# %%
# local imports
import wrangle as w
import explore as e
import modeling as m

# %% [markdown]
# ### Acquire
#
# - Data acquired from data.world
# - Data initially acquired on 23 May 2023
# - It contained 6497 rows and 13 columns before cleaning
# - Each row represents a red or white variant of the Portuguese "Vinho Verde" wine
# - Each column represents a physicochemical property of the wine
# - Quality (target) is the median of at least 3 evaluations made by wine experts from 0 (very bad) to 10 (very excellent)

# %% [markdown]
# ### Prepare
#
# - Identify and handle Nulls
#     - No Nulls
# - Rename columns for readability
# - Verify data types
# - Handle outliers
#     - residual sugar < 33
#     - free sulfur dioxide < 280
#     - chlorides < 0.21
# - Create custom features
# - Encode categorical variables
# - Split data into Train, Validate, Test (approx. 60/20/20)
# - Scale using Standard Scaler for clustering and modeling

# %%
# acquire, clean, and prepare the data
df = w.wrangle_wine()

# split into train, validate, and test
train, validate, test = w.split_data(df)

# %% [markdown]
# #### A brief look at the data

# %%
# taking a peek
train.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4327            6.5              0.35         0.28           12.40      0.051
# 3599            6.8              0.31         0.09            1.40      0.040
# 3081            6.7              0.16         0.49            2.40      0.046
# 1945            5.6              0.34         0.10            1.30      0.031
# 3648            6.3              0.28         0.24            8.45      0.031
#
#       free_so2  total_so2  density    pH  sulphates  alcohol  quality  \
# 4327      86.0      213.0   0.9962  3.16       0.51      9.9        6
# 3599      56.0      145.0   0.9922  3.19       0.46     10.0        5
# 3081      57.0      187.0   0.9952  3.62       0.81     10.4        6
# 1945      20.0       68.0   0.9906  3.36       0.51     11.2        7
# 3648      32.0      172.0   0.9958  3.39       0.57      9.7        7
#
#      wine_type
# 4327     white
# 3599     white
# 3081     white
# ...

# %% [markdown]
# #### Quality Distribution

# %%
# target distribution
e.dist(train)

# %% [markdown]
# ## Explore
# - Is there a difference in quality among wine types (red/white)?
# - Is there a difference for red wine quality among clustered volatile acidity and residual sugar?
# - Is there a difference for white wine quality among clustered volatile acidity and residual sugar?
# - Is there a difference for white wine quality among clustered density and alcohol?
# - Is there a difference for red wine quality among clustered density and alcohol?

# %% [markdown]
# ### Is there a difference in quality among wine types (red/white)?
# * $H_0$: There is **NO** difference between wine type and quality
# * $H_a$: There is a difference between wine type and quality
# * Discrete (wine_type) vs Continuous (quality) = $Mann$-$Whitney$ $U$
#     - $Mann$-$Whitney$ $U$ statistic = 1147368.5
#     - $p$ = 2.370966170733204e-12
# * `Quality` is different based on `wine type`

# %%
# explore wine type and quality
e.type_quality(train,'wine_type','quality')
# Out:
# quality
# ____________________
# Mann-Whitney Test:
#  stat = 1147368.5, p = 2.370966170733204e-12
# ____________________

# %% [markdown]
# **With an alpha of 0.05 (confidence 95%) the p-value is less than alpha. Therefore, evidence suggests that quality is different based on wine type. We believe that splitting `wine_type` for modeling could have a positive impact.**

# %% [markdown]
# ### Is there a difference for red wine quality among clustered volatile acidity and residual sugar?
# * $H_0$: There is **NO** difference between the volatile sugar cluster and quality
# * $H_a$: There is a difference between the volatile sugar cluster and quality
# * Discrete (volatile_sugar) vs Continuous (quality) = $Kruskal$-$Wallis$ $H$
#     - $H$ statistic = 95.33055061649829
#     - $p$ = 1.9917460072373393e-21
# * Red wine `quality` is different based on the `volatile sugar cluster`

# %%
# explore red clustered volatile sugar and quality
e.vol_sug_red_explore(train)
# Out:
# Kruskal-Wallis H-Test:
#  stat = 95.33055061649829, p = 1.9917460072373393e-21

# %% [markdown]
# **With an alpha of 0.05 (confidence 95%) the p-value is less than alpha. Therefore, evidence suggests that there is a difference in quality based on the volatile sugar clusters. We believe that using `volatile_sugar` in the modeling could have a positive impact but not necessarily better than the respective normal features.**

# %% [markdown]
# ### Is there a difference for white wine quality among clustered volatile acidity and residual sugar?
# * $H_0$: There is **NO** difference between the volatile sugar cluster and quality
# * $H_a$: There is a difference between the volatile sugar cluster and quality
# * Discrete (volatile_sugar) vs Continuous (quality) = $Kruskal$-$Wallis$ $H$
#     - $H$ statistic = 48.604135070466924
#     - $p$ = 2.7909121773946287e-11
# * White wine `quality` is different based on the `volatile sugar cluster`

# %%
# explore white clustered density alcohol and quality
e.vol_sug_white_explore(train)
# Out:
# Kruskal-Wallis H-Test:
#  stat = 48.604135070466924, p = 2.7909121773946287e-11

# %% [markdown]
# **With an alpha of 0.05 (confidence 95%) the p-value is less than alpha. Therefore, evidence suggests that there is a difference in quality based on the volatile sugar clusters. We believe that using `volatile_sugar` in the modeling could have a positive impact but not necessarily better than the respective normal features, especially for white wines.**

# %% [markdown]
# ### Is there a difference for white wine quality among clustered density and alcohol?
# * $H_0$: There is **NO** difference between the density alcohol cluster and quality
# * $H_a$: There is a difference between the density alcohol cluster and quality
# * Discrete (density_alcohol) vs Continuous (quality) = $Kruskal$-$Wallis$ $H$
#     - $H$ statistic = 566.524226462482
#     - $p$ = 2.719858256776715e-121
# * White wine `quality` is different based on the `density alcohol cluster`

# %%
# explore red clustered density alcohol and quality
e.den_alc_white_explore(train)
# Out:
# Kruskal-Wallis H-Test:
#  stat = 566.524226462482, p = 2.719858256776715e-121

# %% [markdown]
# **With an alpha of 0.05 (confidence 95%) the p-value is less than alpha. Therefore, evidence suggests that there is a difference in quality based on the density alcohol clusters. We believe that using `density_alcohol` in the modeling could have a positive impact but not necessarily better than the respective normal features.**

# %% [markdown]
# ### Is there a difference for red wine quality among clustered density and alcohol?
# * $H_0$: There is **NO** difference between the density alcohol cluster and quality
# * $H_a$: There is a difference between the density alcohol cluster and quality
# * Discrete (density_alcohol) vs Continuous (quality) = $Kruskal$-$Wallis$ $H$
#     - $H$ statistic = 195.80552619811826
#     - $p$ = 2.996254145256943e-41
# * Red wine `quality` is different based on the `density alcohol cluster`

# %%
# explore red clustered density alcohol and quality
e.den_alc_red_explore(train)
# Out:
# Kruskal-Wallis H-Test:
#  stat = 195.80552619811826, p = 2.996254145256943e-41

# %% [markdown]
# **With an alpha of 0.05 (confidence 95%) the p-value is less than alpha. Therefore, evidence suggests that there is a difference in quality based on the density alcohol clusters. We believe that using `density_alcohol` in the modeling could have a positive impact but not necessarily better than the respective normal features, especially for red wines.**

# %% [markdown]
# ## Exploration Summary
# - Split into two categories for modeling
#     - red wines
#     - white wines
# - Clustering could help but not necessarily be better than normal features
# - Certain clustering features only work for certain wine types

# %% [markdown]
# ### Features for Modeling
# - Features that will be used:
#     - quality (target)
# - Some features that may be useful:
#     - volatile_acidity
#     - residual_sugar
#     - density
#     - alcohol
#     - red cluster volatile_sugar
#     - white cluster density_alcohol

# %% [markdown]
# ## Modeling
# - RMSE will be the evaluation metric
# - Target is quality
# - Using mean of the quality as baseline
#     - Red Baseline Mean: 5.66    RMSE: 0.88
#     - White Baseline Mean: 5.88  RMSE: 0.88
# - Features scaled using Standard Scaler
# - Models will be developed using a few different types, various features, and various hyperparameter configurations
#     - different models for red and white wines
#     - Linear Regression
#     - Polynomial Features through Linear Regression
#     - Polynomial Features with respective KMeans Cluster
#     - Lasso Lars was worse than baseline so left behind
#     - Tweedie Regressor (GLM)
# - Models will be evaluated on Train and Validate
# - Best performing model will only be evaluated on Test
#     - each wine type will have a best model for test

# %%
# get baseline
m.baseline(train,validate)
# Out:
#                   Red          White
# Baseline    Mean: 5.66  Mean: 5.88
# Train       RMSE: 0.88  RMSE:  0.88
# Validate    RMSE: 0.87  RMSE:  0.87

# %%
# split into X and y
# red
Xr_train, Xr_val, Xr_test = train[train.wine_type=='red'].drop(columns=['quality','wine_type']),validate[validate.wine_type=='red'].drop(columns=['quality','wine_type']),test[test.wine_type=='red'].drop(columns=['quality','wine_type'])
yr_train, yr_val, yr_test = train[train.wine_type=='red'][['quality']],validate[validate.wine_type=='red'][['quality']],test[test.wine_type=='red'][['quality']]
# white
Xw_train, Xw_val, Xw_test = train[train.wine_type=='white'].drop(columns=['quality','wine_type']),validate[validate.wine_type=='white'].drop(columns=['quality','wine_type']),test[test.wine_type=='white'].drop(columns=['quality','wine_type'])
yw_train, yw_val, yw_test = train[train.wine_type=='white'][['quality']],validate[validate.wine_type=='white'][['quality']],test[test.wine_type=='white'][['quality']]

# standard scaler
Xrs_train,Xrs_val,Xrs_test = w.std(Xr_train,Xr_val,Xr_test)
Xws_train,Xws_val,Xws_test = w.std(Xw_train,Xw_val,Xw_test)

# %% [markdown]
# ### Best 4 Model Configurations

# %% [markdown]
# #### Linear Regression

# %%
# linear regression results
m.final_models('lr',Xrs_train,Xws_train,yr_train,yw_train,Xrs_val,Xws_val,yr_val,yw_val)
# Out:
# Linear Reg        Red          White
# Train       RMSE: 0.64  RMSE:  0.77
# Validate    RMSE: 0.68  RMSE:  0.74

# %% [markdown]
# #### Polynomial Features

# %%
# polynomial features results
m.final_models('poly',Xrs_train,Xws_train,yr_train,yw_train,Xrs_val,Xws_val,yr_val,yw_val)
# Out:
# Polynomial        Red          White
# Train       RMSE: 0.6  RMSE:  0.71
# Validate    RMSE: 0.69  RMSE:  0.7

# %% [markdown]
# #### Polynomial Features with respective KMeans Cluster

# %%
# poly cluster results
m.cluster_model(Xrs_train,Xws_train,yr_train,yw_train,Xrs_val,Xws_val,yr_val,yw_val)
# Out:
# Linear Reg        Red          White
# Train       RMSE: 0.62  RMSE:  0.75
# Validate    RMSE: 0.68  RMSE:  0.74

# %% [markdown]
# #### Tweedie Regressor

# %%
# tweedie results
m.final_models('tweedie',Xrs_train,Xws_train,yr_train,yw_train,Xrs_val,Xws_val,yr_val,yw_val)
# Out:
# Tweedie           Red          White
# Train       RMSE: 0.68  RMSE:  0.8
# Validate    RMSE: 0.71  RMSE:  0.78

# %% [markdown]
# ### Best to Test
# - Polynomial Features for white wine

# %%
# best model eval with test data
m.test_model(Xrs_train,Xws_train,yr_train,yw_train,Xrs_test,Xws_test,yr_test,yw_test)
# Out:
# Poly Cluster        Red          White
# Test          RMSE: 0.61  RMSE:  0.73

# %% [markdown]
# #### How does it compare?

# %%
# plot predictions vs actual on test
m.plt_err(Xrs_train,Xws_train,yr_train,yw_train,Xrs_test,Xws_test,yr_test,yw_test)

# %% [markdown]
# ### Modeling Wrap Up
# - Clustering helped with predicitons but was not better than normal features
# - White wine quality is more difficult to predict
# - Polynomial Features seems to be the best for both
#     - other red wine models were almost as good

# %% [markdown]
# ## Conclusion
#
# ### Takeaways and Key Findings
# - Predicting wine quality is difficult
#     - Clustering was not better than normal features for predicting wine quality
# - Red wine seems to be a little easier to predict than white wine
#     - Probably easier to taste differences from the tannins compared to white wine
# - Model was better then baseline but not significantly so, and can use improvement
#
# ### Recommendations and Next Steps
# - Since wine quality, as of now, is difficult to predict we would recommend focusing on branding, since quality can be percieved based on brand
# - Given more time we would look at evaluation metrics for clustering
#     - hopefully find better groupings of data using more features
# - Maybe having more data could help
#     - Year of the wine
#     - Grape origin
#     - Grape variety
#     - Price of the wine
#     - Brand
#     - Whether the tastings were done blindly
